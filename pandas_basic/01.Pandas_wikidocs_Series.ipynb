# %%
연습

# %%
# numpy로 array 생성

import numpy as np
arr = np.arange(100,105)
arr
# Out:
# array([100, 101, 102, 103, 104])

# %%
import pandas as pd 
s = pd.Series(arr)
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int32

# %%
s = pd.Series(arr, dtype='int64')
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64

# %%
s = pd.Series(['부장','차장','대리','사원','인턴'])
s
# Out:
# 0    부장
# 1    차장
# 2    대리
# 3    사원
# 4    인턴
# dtype: object

# %%
s = pd.Series([91, 2.5, '스포츠', 4, 5.16])
s
# Out:
# 0      91
# 1     2.5
# 2     스포츠
# 3       4
# 4    5.16
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s[0]
# Out:
# '부장'

# %%
s[::2]
# Out:
# 0    부장
# 2    대리
# 4    인턴
# dtype: object

# %%
s[1::2]
# Out:
# 1    차장
# 3    사원
# dtype: object

# %%
s[np.arange(1,4,2)]
# Out:
# 1    차장
# 3    사원
# dtype: object

# %%
np.random.seed(0)
s = pd.Series(np.random.randint(10000,20000,size=(10,)))
s
# Out:
# 0    12732
# 1    19845
# 2    13264
# 3    14859
# 4    19225
# 5    17891
# 6    14373
# 7    15874
# 8    16744
# 9    13468
# dtype: int32

# %%
s > 15000
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9    False
# dtype: bool

# %%
s[s>15000]
# Out:
# 1    19845
# 4    19225
# 5    17891
# 7    15874
# 8    16744
# dtype: int32

# %%
s = pd.Series(['마케팅','경영','개발','기획','인사'], index=['a','b','c','d','e'])
s
# Out:
# a    마케팅
# b     경영
# c     개발
# d     기획
# e     인사
# dtype: object

# %%
s['c']
# Out:
# '개발'

# %%
s[['b','d']]
# Out:
# b    경영
# d    기획
# dtype: object

# %%
s = pd.Series(['마켓팅','경영','개발','기획','인사'])

# %%
s.index = list('abcde')

# %%
s
# Out:
# a    마켓팅
# b     경영
# c     개발
# d     기획
# e     인사
# dtype: object

# %%
s.values
# Out:
# array(['마켓팅', '경영', '개발', '기획', '인사'], dtype=object)

# %%
s.ndim #Series는 1차원 구조이기 때문에 ndim 출력시 1 출력  >>ndim?? 배열 수 축 수
# Out:
# 1

# %%
s.shape  # 데이터 모양 데이터의 갯수 (튜플) 형식
# Out:
# (5,)

# %%
s = pd.Series(['선화','강호',None,'소정','우영'])
s
# Out:
# 0      선화
# 1      강호
# 2    None
# 3      소정
# 4      우영
# dtype: object

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
s.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
s = pd.Series(['선화','강호',np.nan,'소정','우영'])
s
# Out:
# 0     선화
# 1     강호
# 2    NaN
# 3     소정
# 4     우영
# dtype: object

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
s.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
s[s.isnull()]
# Out:
# 2    NaN
# dtype: object

# %%
s.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
s.notna()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
s[s.notna()]
# Out:
# 0    선화
# 1    강호
# 3    소정
# 4    우영
# dtype: object

# %%
s = pd.Series(np.arange(100,150,10))
s
# Out:
# 0    100
# 1    110
# 2    120
# 3    130
# 4    140
# dtype: int32

# %%
s = pd.Series(range(100,150,10))
s
# Out:
# 0    100
# 1    110
# 2    120
# 3    130
# 4    140
# dtype: int64

# %%
s[1:3]
# Out:
# 1    110
# 2    120
# dtype: int64

# %%
s.index = list('가나다라마')
s
# Out:
# 가    100
# 나    110
# 다    120
# 라    130
# 마    140
# dtype: int64

# %%
s['나':'라']
# Out:
# 나    110
# 다    120
# 라    130
# dtype: int64

# %%
예제

# %%
1. Series를 float32가 되도록 생성

# %%
import pandas as pd 

s = pd.Series(range(3,12,2), dtype='float32')
s
# Out:
# 0     3.0
# 1     5.0
# 2     7.0
# 3     9.0
# 4    11.0
# dtype: float32

# %%
2.

# %%
s = pd.Series(['가','나','다','라','마'])
s
# Out:
# 0    가
# 1    나
# 2    다
# 3    라
# 4    마
# dtype: object

# %%
s = pd.Series(list('가나다라마'))
s
# Out:
# 0    가
# 1    나
# 2    다
# 3    라
# 4    마
# dtype: object

# %%
3.

# %%
s = pd.Series(range(10,51,10), index=['가','나','다','라','마'])
s
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %%
s = pd.Series(np.arange(10,51,10))
s.index = ['가','나','다','라','마']
s
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int32

# %%
s = pd.Series(range(10,60,10), index=list('가나다라마'))
s
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %%
s = pd.Series(range(10,51,10))
s.index = list('가나다라마')
s
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %%
4. 나 라 데이터만 조회

# %%
s[[1,3]]
# Out:
# 나    20
# 라    40
# dtype: int32

# %%
s[1:4:2]
# Out:
# 나    20
# 라    40
# dtype: int64

# %%
s[['나','라']]
# Out:
# 나    20
# 라    40
# dtype: int64

# %%
s['나':'라':2]
# Out:
# 나    20
# 라    40
# dtype: int64

# %%
5. 160 이하인 데이터만 필터

# %%
np.random.seed(0)

sample2 = pd.Series(np.random.randint(100,200,size=(15,)))
sample2
# Out:
# 0     144
# 1     147
# 2     164
# 3     167
# 4     167
# 5     109
# 6     183
# 7     121
# 8     136
# 9     187
# 10    170
# 11    188
# 12    188
# 13    112
# 14    158
# dtype: int32

# %%
sample2[sample2 <= 160]
# Out:
# 0     144
# 1     147
# 5     109
# 7     121
# 8     136
# 13    112
# 14    158
# dtype: int32

# %%
7.

# %%
sample2[(130 <= sample2)& (sample2 <= 170)]
# Out:
# 0     144
# 1     147
# 2     164
# 3     167
# 4     167
# 8     136
# 10    170
# 14    158
# dtype: int32

# %%
8. 시리즈 생성

# %%
s = pd.Series(['apple',np.nan,'banana','kiwi','gubong'], index=['가','나','다','라','마'])
s
# Out:
# 가     apple
# 나       NaN
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: object

# %%
9. 결측치 데이터만 필터

# %%
sample = pd.Series(['IT서비스',np.nan,'반도체',np.nan,'바이오','자율주행'])
sample
# Out:
# 0    IT서비스
# 1      NaN
# 2      반도체
# 3      NaN
# 4      바이오
# 5     자율주행
# dtype: object

# %%
sample[sample.notnull()]
# Out:
# 0    IT서비스
# 2      반도체
# 4      바이오
# 5     자율주행
# dtype: object

# %%
10. 슬라이싱

# %%
np.random.seed(0)
sample = pd.Series(np.random.randint(100,200, size=(10,)))
sample
# Out:
# 0    144
# 1    147
# 2    164
# 3    167
# 4    167
# 5    109
# 6    183
# 7    121
# 8    136
# 9    187
# dtype: int32

# %%
sample[2:7]
# Out:
# 2    164
# 3    167
# 4    167
# 5    109
# 6    183
# dtype: int32

# %%
11.슬라이싱

# %%
np.random.seed(0)
sample = pd.Series(np.random.randint(100,200, size=(10,)), index=list('가나다라마바사아자차'))
sample
# Out:
# 가    144
# 나    147
# 다    164
# 라    167
# 마    167
# 바    109
# 사    183
# 아    121
# 자    136
# 차    187
# dtype: int32

# %%
sample['바':]
# Out:
# 바    109
# 사    183
# 아    121
# 자    136
# 차    187
# dtype: int32

# %%
sample[:'다'] # Series 에서 슬라이싱 하면 인덱스 값 포함해서 나옴
# Out:
# 가    144
# 나    147
# 다    164
# dtype: int32

# %%
sample['나':'바']
# Out:
# 나    147
# 다    164
# 라    167
# 마    167
# 바    109
# dtype: int32
